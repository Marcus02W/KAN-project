# %%
# local imports
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '../src'))
from MLP_VIS import simple_mlp_vis, mlp_weights_vis, mlp_inference_vis

# global imports
from torch import load
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np

# %%
# Load the PyTorch model
#mlp = load('../models/California_Housing_MLP_OPT.pth')
mlp = load('../models/MNIST_MLP_OPT.pth')

mlp
# Out:
# MLP(
#   (network): Sequential(
#     (0): Linear(in_features=64, out_features=25, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.07726383578281804, inplace=False)
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.07726383578281804, inplace=False)
#     (6): Linear(in_features=25, out_features=10, bias=True)
#     (7): Softmax(dim=1)
#   )
# )

# %%
img = simple_mlp_vis(mlp)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1549.5, 769.5, -0.5)

# %%
img = mlp_weights_vis(mlp)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1549.5, 769.5, -0.5)

# %%
input = np.array(Image.open('1.jpg').convert('L'))

img = mlp_inference_vis(mlp, input)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1549.5, 769.5, -0.5)
