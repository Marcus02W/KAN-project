# %%
# local imports
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '../src'))
from MLP_VIS import simple_mlp_vis, mlp_weights_vis

# global imports
from torch import load
from matplotlib import pyplot as plt

# %%
# Load the PyTorch model
mlp = load('../models/California_Housing_MLP_OPT.pth')

mlp
# Out:
# MLP(
#   (network): Sequential(
#     (0): Linear(in_features=13, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.05006828929668337, inplace=False)
#     (3): Linear(in_features=32, out_features=32, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.05006828929668337, inplace=False)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.05006828929668337, inplace=False)
#     (9): Linear(in_features=32, out_features=1, bias=True)
#     (10): ReLU()
#   )
# )

# %%
img = simple_mlp_vis(mlp)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1549.5, 769.5, -0.5)

# %%
img = mlp_weights_vis(mlp)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1549.5, 769.5, -0.5)
